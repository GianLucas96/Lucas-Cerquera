# %% [markdown]
# <a href="https://colab.research.google.com/github/GianLucas96/Lucas-Cerquera/blob/Lucas_Cerquera/ok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
from google.colab import files


files.upload()


print('Hola')
# Out:
#      <input type="file" id="files-fcb2bd4c-0456-450f-8dc2-388791d3dbde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fcb2bd4c-0456-450f-8dc2-388791d3dbde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_FIFA.csv to data_FIFA.csv
# Hola

# %%
path = 'data_FIFA.csv'

data_fifa = pd.read_csv(path, sep=',')
data_fifa.columns


data1 = data_fifa[['Name','Age','Nationality','Overall','Potential','Club','Value','Wage','Position','Release Clause','International Reputation']]
print(data1.info())
data1.dropna(axis=0,inplace=True)
data1.head(10)
print(data1.info())


def Str_Con__Unidades(valor):
    
    """
    Esta funcion permite converitr los str de dinero
    en su valor numerico a partir de su Letra 
    """
    if valor[-1] == 'M':
        return float(valor[1:-1])*1000000
    elif valor[-1] == 'K':
        return float(valor[1:-1])*1000
    else:
        return float(valor[1:])
             
             
data1['Value'] = data1['Value'].apply(lambda x: Str_Con__Unidades(x) / 1000000)
data1['Wage'] = data1['Wage'].apply(lambda x: Str_Con__Unidades(x) / 1000)
data1['Release Clause'] = data1['Release Clause'].apply(lambda x: Str_Con__Unidades(x) / 1000000)

data1['International Reputation'] = data1['International Reputation'].astype(str )
data1.describe()


cols = ['Age','Overall','Potential','Value','Wage','Release Clause']

fig = px.scatter_matrix(data1,
    dimensions=cols,
    hover_name="Name",title='MATRIZ DE DISPERCIÓN',
    color ='Position')

fig.update_layout(
    title='Iris Data set',
    width=1200,
    height=1000,
)


fig.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      17966 non-null  object
#  6   Value                     18207 non-null  object
#  7   Wage                      18207 non-null  object
#  8   Position                  18147 non-null  object
#  9   Release Clause            16643 non-null  object
#  10  International Reputation  18159 non-null  float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16643 entries, 0 to 18206
# ...
